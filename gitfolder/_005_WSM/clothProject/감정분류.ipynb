# %% [markdown]
# <a href="https://colab.research.google.com/github/rambus2006/Web/blob/master/%EA%B0%90%EC%A0%95%EB%B6%84%EB%A5%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LG지니어스 5차시: 자연어 모델 만들기

# %%
print("Hello World")
# Out:
# Hello World

# %%
#패키지 설치를 위해 셀을 추가 
# !pip install transformers
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 52.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 24.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 102.1 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.8 MB/s eta 0:00:00
# ...

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available()else 'cpu')
device
# Out:
# device(type='cuda')

# %%
import warnings

warnings.filterwarnings(action="ignore")

# %%
from datasets import load_dataset

dataset= load_dataset('nsmc')
# Out:
# ...
# Generating test split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Dataset nsmc downloaded and prepared to /root/.cache/huggingface/datasets/nsmc/default/1.1.0/bfd4729bf1a67114e5267e6916b9e4807010aeb238e4a3c2b95fbfa3a014b5f3. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'document', 'label'],
#         num_rows: 150000
#     })
#     test: Dataset({
#         features: ['id', 'document', 'label'],
#         num_rows: 50000
#     })
# })

# %%
train_data = dataset['train'].shuffle(seed=42).select(range(2000))
test_data = dataset['test'].shuffle(seed=42).select(range(2000))

# %%
train_data
# Out:
# Dataset({
#     features: ['id', 'document', 'label'],
#     num_rows: 2000
# })

# %%
test_data
# Out:
# Dataset({
#     features: ['id', 'document', 'label'],
#     num_rows: 2000
# })

# %%
MODEL_NAME = 'bert-base-multilingual-cased'

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
tokenizer.tokenize(train_data['document'][0])
# Out:
# ['For',
#  'Carl',
#  '.',
#  '칼',
#  '세',
#  '##이',
#  '##건',
#  '##으로',
#  '시',
#  '##작',
#  '##해서',
#  '칼',
#  '세',
#  '##이',
#  '##건',
#  '##으로',
#  '끝',
#  '##난',
#  '##다',
#  '.']

# %%
train_encoding = tokenizer(train_data['document'], return_tensors='pt', padding=True, turncation=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-ad8cd8a62f20> in <cell line: 1>()
# ----> 1 train_encoding = tokenizer(train_data['document'], return_tensors='pt', padding=True, turncation=True)
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in __call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2546             if not self._in_target_context_manager:
#    2547                 self._switch_to_input_mode()
# -> 2548             encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
# ...
